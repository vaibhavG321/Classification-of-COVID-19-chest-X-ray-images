# %% [markdown]
# <a href="https://colab.research.google.com/github/adig2208/Classification-of-COVID-19-chest-X-ray-images/blob/master/test1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q kaggle

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-29a52fd6-10fc-42be-afe7-b4ab9bda48ca" name="files[]" multiple disabled />
#      <output id="result-29a52fd6-10fc-42be-afe7-b4ab9bda48ca">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# {'kaggle.json': b'{"username":"adityagurnani","key":"5e0e6edf13af5e1433d09f6337cbd2dc"}'}

# %%
 ! mkdir ~/.kaggle
 # !cp kaggle.json ~/.kaggle/

 #change permission
 # !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d paultimothymooney/chest-xray-pneumonia
# Out:
# ...
# 100% 2.29G/2.29G [00:29<00:00, 41.9MB/s]
# 100% 2.29G/2.29G [00:30<00:00, 82.1MB/s]

# %%
from zipfile import ZipFile
file_name = 'chest-xray-pneumonia.zip'

with ZipFile(file_name,'r') as zip:
  zip.extractall()
  print('done')
# Out:
# done

# %%
import random
KAGGLE_FILE_PATH = '/content/chest_xray/train/NORMAL'
TARGET_NORMAL_DIR = '/content/chest_xray/chest_xray/NORM'

# %%
image_names = os.listdir(KAGGLE_FILE_PATH)

# %%
image_names
# Out:
# ['IM-0341-0001.jpeg',
#  'NORMAL2-IM-1419-0001.jpeg',
#  'NORMAL2-IM-0522-0001.jpeg',
#  'NORMAL2-IM-0559-0001.jpeg',
#  'IM-0277-0001.jpeg',
#  'IM-0459-0001.jpeg',
#  'IM-0182-0001.jpeg',
#  'IM-0298-0001.jpeg',
#  'NORMAL2-IM-0699-0001.jpeg',
#  'IM-0701-0001.jpeg',
#  'NORMAL2-IM-1236-0001.jpeg',
#  'NORMAL2-IM-0402-0001.jpeg',
#  'NORMAL2-IM-1190-0001.jpeg',
#  'IM-0544-0001.jpeg',
#  'NORMAL2-IM-1310-0001.jpeg',
#  'IM-0523-0001.jpeg',
#  'NORMAL2-IM-0946-0001.jpeg',
#  'IM-0187-0001.jpeg',
#  'IM-0357-0001.jpeg',
#  'IM-0348-0001.jpeg',
#  'NORMAL2-IM-0472-0001.jpeg',
#  'IM-0444-0001.jpeg',
#  'IM-0162-0001.jpeg',
#  'IM-0664-0001.jpeg',
#  'NORMAL2-IM-1311-0001.jpeg',
#  'IM-0473-0001.jpeg',
#  'IM-0339-0001.jpeg',
#  'NORMAL2-IM-0385-0001.jpeg',
#  'IM-0420-0001.jpeg',
#  'NORMAL2-IM-1106-0001.jpeg',
#  'NORMAL2-IM-0971-0001-0002.jpeg',
#  'IM-0525-0001-0002.jpeg',
#  'NORMAL2-IM-1242-0001.jpeg',
#  'NORMAL2-IM-0834-0001.jpeg',
#  'NORMAL2-IM-0826-0001.jpeg',
# ...

# %%
random.shuffle(image_names)

# %%
 import pandas as pd
import os
import shutil

# %%
for i in range(200):
  image_name=image_names[i]
  image_path=os.path.join(KAGGLE_FILE_PATH,image_name)
  target_path=os.path.join(TARGET_NORMAL_DIR,image_name)
  shutil.copy2(image_path,target_path)
  print("copying image",i)
# Out:
# copying image 0
# copying image 1
# copying image 2
# copying image 3
# copying image 4
# copying image 5
# copying image 6
# copying image 7
# copying image 8
# copying image 9
# copying image 10
# copying image 11
# copying image 12
# copying image 13
# copying image 14
# copying image 15
# copying image 16
# copying image 17
# copying image 18
# copying image 19
# copying image 20
# copying image 21
# copying image 22
# copying image 23
# copying image 24
# copying image 25
# copying image 26
# copying image 27
# copying image 28
# copying image 29
# copying image 30
# copying image 31
# copying image 32
# copying image 33
# copying image 34
# copying image 35
# copying image 36
# copying image 37
# copying image 38
# copying image 39
# copying image 40
# copying image 41
# copying image 42
# copying image 43
# copying image 44
# copying image 45
# copying image 46
# copying image 47
# copying image 48
# copying image 49
# copying image 50
# copying image 51
# copying image 52
# ...

# %%
FILE_PATH = '/content/Data_Entry_2017.csv'
IMAGE_PATH= '/content/images_001/images'

# %%
df = pd.read_csv(FILE_PATH)
print (df.shape)
# Out:
# (112120, 12)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
filename = "kerasmodel" #@param {type:"string"}
folders_or_files_to_save = "keras_model.h5" #@param {type:"string"}
from google.colab import files
from google.colab import auth
from googleapiclient.http import MediaFileUpload
from googleapiclient.discovery import build

def save_file_to_drive(name, path):
    file_metadata = {
    'name': name,
    'mimeType': 'application/octet-stream'
    }

    media = MediaFileUpload(path, 
                  mimetype='application/octet-stream',
                  resumable=True)

    created = drive_service.files().create(body=file_metadata, media_body=media, fields='id').execute()

    print('File ID: {}'.format(created.get('id')))

    return created


extension_zip = ".zip"

zip_file = '/content/chest_xray/chest_xray/NORM' + extension_zip

# !rm -rf $zip_file
# !zip -r $zip_file {'/content/chest_xray/chest_xray/NORM'} # FOLDERS TO SAVE INTO ZIP FILE

auth.authenticate_user()
drive_service = build('drive', 'v3')

destination_name = zip_file
path_to_file = zip_file
save_file_to_drive(destination_name, path_to_file)
# Out:
#   adding: content/chest_xray/chest_xray/NORM/ (stored 0%)
#   adding: content/chest_xray/chest_xray/NORM/IM-0341-0001.jpeg (deflated 1%)
#   adding: content/chest_xray/chest_xray/NORM/NORMAL2-IM-1419-0001.jpeg (deflated 6%)
#   adding: content/chest_xray/chest_xray/NORM/IM-0182-0001.jpeg (deflated 1%)
#   adding: content/chest_xray/chest_xray/NORM/NORMAL2-IM-1236-0001.jpeg (deflated 1%)
#   adding: content/chest_xray/chest_xray/NORM/IM-0525-0001-0002.jpeg (deflated 1%)
#   adding: content/chest_xray/chest_xray/NORM/NORMAL2-IM-0834-0001.jpeg (deflated 0%)
#   adding: content/chest_xray/chest_xray/NORM/IM-0276-0001.jpeg (deflated 1%)
#   adding: content/chest_xray/chest_xray/NORM/IM-0279-0001.jpeg (deflated 1%)
#   adding: content/chest_xray/chest_xray/NORM/IM-0590-0001.jpeg (deflated 0%)
#   adding: content/chest_xray/chest_xray/NORM/NORMAL2-IM-0917-0001.jpeg (deflated 1%)
#   adding: content/chest_xray/chest_xray/NORM/NORMAL2-IM-0945-0001.jpeg (deflated 1%)
# ...
